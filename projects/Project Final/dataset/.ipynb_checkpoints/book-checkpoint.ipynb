# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('buku.csv')

# %%
 df['year'] = df['publication_date'].str[-4:]

# %%
df.drop(columns=['publication_date'], inplace=True)

# %%
df.head(3)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
#
#                        authors  average_rating        isbn language_code  \
# 0  J.K. Rowling/Mary GrandPr̩            4.57  0439785960           eng
# 1  J.K. Rowling/Mary GrandPr̩            4.49  0439358078           eng
# 2                 J.K. Rowling            4.42  0439554896           eng
#
#      num_pages  ratings_count  text_reviews_count  year
# 0          652        2095690               27591  2006
# 1          870        2153167               29221  2004
# 2          352           6333                 244  2003

# %%
df.to_csv('buku.csv', index=False)

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'language_code',
#        '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
kolom = df.columns

# %%
df.describe()
# Out:
#              bookID  average_rating     num_pages  ratings_count  \
# count  11123.000000    11123.000000  11123.000000   1.112300e+04
# mean   21310.856963        3.934075    336.405556   1.794285e+04
# std    13094.727252        0.350485    241.152626   1.124992e+05
# min        1.000000        0.000000      0.000000   0.000000e+00
# 25%    10277.500000        3.770000    192.000000   1.040000e+02
# 50%    20287.000000        3.960000    299.000000   7.450000e+02
# 75%    32104.500000        4.140000    416.000000   5.000500e+03
# max    45641.000000        5.000000   6576.000000   4.597666e+06
#
#        text_reviews_count
# count        11123.000000
# mean           542.048099
# std           2576.619589
# min              0.000000
# 25%              9.000000
# 50%             47.000000
# 75%            238.000000
# max          94265.000000

# %%
df = df.drop(df.loc[df['num_pages']==0].index)

# %%
df.shape
# Out:
# (11047, 11)

# %%
df.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# language_code         0
# num_pages             0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# year                  0
# dtype: int64

# %%
df['language_code'].unique()
# Out:
# array(['eng', 'en-US', 'fre', 'spa', 'en-GB', 'mul', 'grc', 'enm',
#        'en-CA', 'ger', 'jpn', 'ara', 'nl', 'zho', 'lat', 'por', 'srp',
#        'ita', 'rus', 'msa', 'glg', 'wel', 'swe', 'nor', 'tur', 'gla',
#        'ale'], dtype=object)

# %%
df['language_code'].loc[(df['language_code']=='en-US') | (df['language_code']=='en-GB') | (df['language_code']=='en-CA')] = 'eng'

# %%
df['language_code'].unique()
# Out:
# array(['eng', 'fre', 'spa', 'mul', 'grc', 'enm', 'ger', 'jpn', 'ara',
#        'nl', 'zho', 'lat', 'por', 'srp', 'ita', 'rus', 'msa', 'glg',
#        'wel', 'swe', 'nor', 'tur', 'gla', 'ale'], dtype=object)

# %%
df[(df['language_code']=='en-US') ]
# Out:
# Empty DataFrame
# Columns: [bookID, title, authors, average_rating, isbn, language_code, num_pages, ratings_count, text_reviews_count, publication_date, year]
# Index: []

# %%
df.loc[df['ratings_count']>100].sort_values('average_rating', ascending=False)
# Out:
#       bookID                                              title  \
# 6587   24812                     The Complete Calvin and Hobbes
# 4          8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 6589   24814      It's a Magical World (Calvin and Hobbes  #11)
# 6         10       Harry Potter Collection (Harry Potter  #1-6)
# 1848    6550                                        Early Color
# ...      ...                                                ...
# 4651   16717                              You Don't Love Me Yet
# 5203   18829                                         Yellow Dog
# 5165   18722                                      Alentejo Blue
# 9269   36402      The Governess\t or  The Little Female Academy
# 8812   33993                                       Citizen Girl
#
#                            authors  average_rating        isbn language_code  \
# 6587                Bill Watterson            4.82  0740748475           eng
# ...

# %%
df.sort_values('average_rating', ascending=False)
# Out:
#        bookID                                              title  \
# 624      2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 10262   41639         Bill Gates: Computer Legend (Famous Lives)
# 8544    32823       Fanning the Flame: Bible  Cross  and Mission
# 9324    36853                 Tyrannosaurus Wrecks (Stanley  #1)
# 786      2560                  Willem de Kooning: Late Paintings
# ...       ...                                                ...
# 4241    15186                                American Film Guide
# 10138   41044                                      Day and Night
# 6558    24749                  American Writers  Supplement VIII
# 11027   45259  Anthony Thwaite: In Conversation With Peter Da...
# 6380    24010         Laguna  I Love You: The Best of "Our Town"
#
#                                                  authors  average_rating  \
# 624                  Aristophanes/F.W. Hall/W.M. Geldart             5.0
# ...

# %%
df.groupby('language_code')['title'].count().sort_values(ascending=False).plot(kind='bar').set_yscale('log')

# %%
df.loc[df['average_rating']>=4]['num_pages'].min()
# Out:
# 1

# %%
df.loc[df['ratings_count']>100].groupby('year')['average_rating'].max().plot()

# %%
kolom
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'language_code',
#        'num_pages', 'ratings_count', 'text_reviews_count', 'publication_date',
#        'year'],
#       dtype='object')

# %%
df.sort_values('ratings_count', ascending=False).head(10)[['title', 'ratings_count']].set_index('title')
# Out:
#                                                     ratings_count
# title
# Twilight (Twilight  #1)                                   4597666
# The Hobbit  or There and Back Again                       2530894
# The Catcher in the Rye                                    2457092
# Angels & Demons (Robert Langdon  #1)                      2418736
# Harry Potter and the Prisoner of Azkaban (Harry...        2339585
# Harry Potter and the Chamber of Secrets (Harry ...        2293963
# Harry Potter and the Order of the Phoenix (Harr...        2153167
# The Fellowship of the Ring (The Lord of the Rin...        2128944
# Animal Farm                                               2111750
# Harry Potter and the Half-Blood Prince (Harry P...        2095690

# %%
df.sort_values('ratings_count', ascending=False).head(10)[['title', 'average_rating']].set_index('title').sort_values('average_rating').plot.barh().legend(bbox_to_anchor=(1,1))

# %%
df.sort_values('ratings_count', ascending=False).head(10)[['title', 'ratings_count']].set_index('title').plot.barh()#.set_xscale('log')

# %%
df.sort_values('text_reviews_count', ascending=False).head(10)[['title', 'text_reviews_count']].set_index('title').plot.barh()

# %%
df.loc[df['text_reviews_count']>100].sort_values('average_rating').head(10)[['title', 'average_rating']].set_index('title').plot.barh()
